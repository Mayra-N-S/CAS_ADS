# %% [markdown]
# ## Tutorial II: Optimization in **pytorch** and NN introduction
#
# <p>
# Bern Winter School on Machine Learning, 2024<br>
# Prepared by Mykhailo Vladymyrov and Matthew Vowels.
# </p>
#
# This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %%
# time to teach without exercises 50mins

# %% [markdown]
# ## 1. Load necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ## 2. Linear fit
#
# Here we will solve optimization problem to perform linear regression. First we will generate training set of 80 data points and test set of 20, laying on a line with a random offset $$y = a_0 x + b_0 + \delta,$$ where $\delta$ is a random variable sampled from a uniform distribution with standard deviation equal to $s_0$.
# <!-- o.f.: 46, 48, 87, 99 | val better than train: 47, 56, 86. -->

# %%
a0 = 3  # 3
b0 = 5  # 5
s0 = 1  # 1

n_all = 100

np.random.seed(99) #Notiz: Mit diesem Seed erhält man immer dieselben Random Werte, auch wenn man den Code mehrmals neu laufen lässt

# all samples
x_all = np.linspace(0, 10, n_all)  # 100 points
d_all = np.random.uniform(-s0, s0, size=n_all)
y_all = np.asarray([a0*x + b0 + d for x, d in zip(x_all, d_all)])

# randomize order and get 80% for training
idx = np.random.permutation(n_all)
n_train = n_all * 80 // 100

idx_train = idx[0:n_train]
idx_val = idx[n_train:]

x_train, y_train = x_all[idx_train], y_all[idx_train]

x_val, y_val = x_all[idx_val], y_all[idx_val]

plt.plot(x_train, y_train, "or", x_val, y_val, "b^")
plt.legend(('training points', 'validation points'),  loc='upper left');

# %% [markdown]
# We will then define loss function as the mean of squared residuals (distance from line along $y$) for the points.
#
# We will use [stochactic gradient descent](https://en.wikipedia.org/wiki/Stochastic_gradient_descent): on each iteration use only a fraction (`batch_size`) of all training set. In many cases training set is huge and cannot be fed on each iteration in principle. Also it can sometimes help the optimizer to properly explore the manifold.

# %%
class Linear(nn.Module):
    def __init__(self):
        super(Linear, self).__init__()
        self.a = nn.Parameter(torch.randn(1, requires_grad=True))
        self.b = nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        return self.a * x + self.b


def loss_f(true_y, y_predicted):
    return F.mse_loss(y_predicted, true_y)

# %%
len(x_train)
# Out:
# 80

# %%
# Define the model
model = Linear()

# Define the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.002) #Was sie sagte (What she said): lr between 10 and -4 always gives good results

# Define the number of epochs and batch size
epochs = 400
batch_size = 10 # Notiz: Man braucht normalerweise Batches, damit es schneller ausführt. Bei diesem
#Beispiel ist das Datenset klein, deshalb macht es eigentlich kein Unterschied, ob wir Batches machen oder nicht..


x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
y_train = torch.tensor(y_train)

x_val = torch.tensor(x_val)
y_val = torch.tensor(y_val)



# Training loop
train_loss_history = []
val_loss_history = []
for epoch in range(epochs):
    model.train()  # as opposed to model.eval()
    batch_losses = []
    permutation = torch.randperm(x_train.size()[0])


    for i in range(0, x_train.size()[0], batch_size):
        optimizer.zero_grad()

        indices = permutation[i:i+batch_size]
        batch_x, batch_y = x_train[indices], y_train[indices]

        # Forward pass
        outputs = model(batch_x)

        # Compute the loss
        loss = loss_f(batch_y, outputs)
        batch_losses.append(loss.item())
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    average_training_loss = np.mean(batch_losses)
    train_loss_history.append(average_training_loss)

    # Validation step (optional, for monitoring performance) # Noitz: Here we evaluate our Model
    model.eval()
    with torch.no_grad():
        val_outputs = model(x_val)
        val_loss = loss_f(y_val, val_outputs)
        val_loss_history.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss.item()}")
# Out:
# <ipython-input-17-7fdb20e6e018>:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
# <ipython-input-17-7fdb20e6e018>:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train)
# <ipython-input-17-7fdb20e6e018>:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_val = torch.tensor(x_val)
# <ipython-input-17-7fdb20e6e018>:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val = torch.tensor(y_val)
# Epoch 1/400, Validation Loss: 39.97376947764724
# Epoch 2/400, Validation Loss: 9.102999838728367
# Epoch 3/400, Validation Loss: 6.279713609343506
# Epoch 4/400, Validation Loss: 5.953175953270277
# Epoch 5/400, Validation Loss: 5.8491779530081764
# Epoch 6/400, Validation Loss: 5.7585351701819
# Epoch 7/400, Validation Loss: 5.666797567000428
# Epoch 8/400, Validation Loss: 5.570286494671246
# Epoch 9/400, Validation Loss: 5.480788366887245
# Epoch 10/400, Validation Loss: 5.3937575839252565
# Epoch 11/400, Validation Loss: 5.305468972902178
# Epoch 12/400, Validation Loss: 5.233910026332351
# Epoch 13/400, Validation Loss: 5.135372380492683
# Epoch 14/400, Validation Loss: 5.0566925180071225
# Epoch 15/400, Validation Loss: 4.975069777721013
# Epoch 16/400, Validation Loss: 4.896517941216656
# Epoch 17/400, Validation Loss: 4.818167239360478
# Epoch 18/400, Validation Loss: 4.74860175600502
# Epoch 19/400, Validation Loss: 4.673795218652597
# Epoch 20/400, Validation Loss: 4.590249300891927
# Epoch 21/400, Validation Loss: 4.521160201583677
# Epoch 22/400, Validation Loss: 4.444853342092461
# Epoch 23/400, Validation Loss: 4.3707570125746225
# Epoch 24/400, Validation Loss: 4.302367635442415
# Epoch 25/400, Validation Loss: 4.234813319624933
# Epoch 26/400, Validation Loss: 4.174772007865001
# Epoch 27/400, Validation Loss: 4.097776498347542
# Epoch 28/400, Validation Loss: 4.043403951571776
# Epoch 29/400, Validation Loss: 3.9695299860049915
# Epoch 30/400, Validation Loss: 3.922111693896112
# Epoch 31/400, Validation Loss: 3.8479421050377534
# Epoch 32/400, Validation Loss: 3.7930940895584846
# Epoch 33/400, Validation Loss: 3.744050532885244
# Epoch 34/400, Validation Loss: 3.6668208692622337
# Epoch 35/400, Validation Loss: 3.615450614034254
# Epoch 36/400, Validation Loss: 3.5586272140250315
# Epoch 37/400, Validation Loss: 3.499850257149145
# Epoch 38/400, Validation Loss: 3.4487539612389795
# Epoch 39/400, Validation Loss: 3.4051679350768276
# Epoch 40/400, Validation Loss: 3.3426587162121857
# Epoch 41/400, Validation Loss: 3.2883901035406224
# Epoch 42/400, Validation Loss: 3.244581560634429
# Epoch 43/400, Validation Loss: 3.1934859133578084
# Epoch 44/400, Validation Loss: 3.132731736525028
# Epoch 45/400, Validation Loss: 3.087736923535044
# Epoch 46/400, Validation Loss: 3.037606429945
# Epoch 47/400, Validation Loss: 2.993600817359024
# Epoch 48/400, Validation Loss: 2.944355462473301
# Epoch 49/400, Validation Loss: 2.9105341610806077
# Epoch 50/400, Validation Loss: 2.8500550981616466
# Epoch 51/400, Validation Loss: 2.8096506207703578
# Epoch 52/400, Validation Loss: 2.7630530759842338
# Epoch 53/400, Validation Loss: 2.7169992575140314
# Epoch 54/400, Validation Loss: 2.6749071864480447
# Epoch 55/400, Validation Loss: 2.6349073309765396
# Epoch 56/400, Validation Loss: 2.5945154750207062
# Epoch 57/400, Validation Loss: 2.554555648974358
# Epoch 58/400, Validation Loss: 2.5191258431188106
# Epoch 59/400, Validation Loss: 2.48404886181777
# Epoch 60/400, Validation Loss: 2.4429099507788274
# Epoch 61/400, Validation Loss: 2.4192397024310295
# Epoch 62/400, Validation Loss: 2.3947794281398225
# Epoch 63/400, Validation Loss: 2.3391365057800733
# Epoch 64/400, Validation Loss: 2.3031598775196995
# Epoch 65/400, Validation Loss: 2.277848650443917
# Epoch 66/400, Validation Loss: 2.2533073761076965
# Epoch 67/400, Validation Loss: 2.2138919542335804
# Epoch 68/400, Validation Loss: 2.1716151716576126
# Epoch 69/400, Validation Loss: 2.1314444740225253
# Epoch 70/400, Validation Loss: 2.1097257791769026
# Epoch 71/400, Validation Loss: 2.0711646944349194
# Epoch 72/400, Validation Loss: 2.0369910814823893
# Epoch 73/400, Validation Loss: 2.009102751590171
# Epoch 74/400, Validation Loss: 1.9808168825698058
# Epoch 75/400, Validation Loss: 1.9520896374974108
# Epoch 76/400, Validation Loss: 1.921239076850871
# Epoch 77/400, Validation Loss: 1.8945092019793968
# Epoch 78/400, Validation Loss: 1.8733398608774467
# Epoch 79/400, Validation Loss: 1.8385221758087134
# Epoch 80/400, Validation Loss: 1.8122887654168747
# Epoch 81/400, Validation Loss: 1.7873918524266876
# Epoch 82/400, Validation Loss: 1.7619182464781347
# Epoch 83/400, Validation Loss: 1.7419206584646811
# Epoch 84/400, Validation Loss: 1.7122986477406847
# Epoch 85/400, Validation Loss: 1.684146811626979
# Epoch 86/400, Validation Loss: 1.663822194263662
# Epoch 87/400, Validation Loss: 1.6377142672532834
# Epoch 88/400, Validation Loss: 1.6112632421662951
# Epoch 89/400, Validation Loss: 1.5949283226260866
# Epoch 90/400, Validation Loss: 1.5828272873894007
# Epoch 91/400, Validation Loss: 1.5587667992914473
# Epoch 92/400, Validation Loss: 1.5311237483468383
# Epoch 93/400, Validation Loss: 1.5100079829146433
# Epoch 94/400, Validation Loss: 1.4873650068565296
# Epoch 95/400, Validation Loss: 1.4702494456243773
# Epoch 96/400, Validation Loss: 1.4492064424677988
# Epoch 97/400, Validation Loss: 1.4207792857358068
# Epoch 98/400, Validation Loss: 1.4087838300308106
# Epoch 99/400, Validation Loss: 1.3885366456420598
# Epoch 100/400, Validation Loss: 1.3651587839518375
# Epoch 101/400, Validation Loss: 1.3523963430196693
# Epoch 102/400, Validation Loss: 1.3351293991773499
# Epoch 103/400, Validation Loss: 1.3173725631257618
# Epoch 104/400, Validation Loss: 1.2949675901697804
# Epoch 105/400, Validation Loss: 1.2779828390973946
# Epoch 106/400, Validation Loss: 1.2588847317052991
# Epoch 107/400, Validation Loss: 1.245550230198841
# Epoch 108/400, Validation Loss: 1.2326771507011196
# Epoch 109/400, Validation Loss: 1.2160380355552678
# Epoch 110/400, Validation Loss: 1.203070162276179
# Epoch 111/400, Validation Loss: 1.1808745985918883
# Epoch 112/400, Validation Loss: 1.1690731339134701
# Epoch 113/400, Validation Loss: 1.1500840833133141
# Epoch 114/400, Validation Loss: 1.136992260380921
# Epoch 115/400, Validation Loss: 1.1322956110071147
# Epoch 116/400, Validation Loss: 1.1092801524391258
# Epoch 117/400, Validation Loss: 1.097322273558834
# Epoch 118/400, Validation Loss: 1.094446247101943
# Epoch 119/400, Validation Loss: 1.0798799271986748
# Epoch 120/400, Validation Loss: 1.0557974325518953
# Epoch 121/400, Validation Loss: 1.0503359974370226
# Epoch 122/400, Validation Loss: 1.033423412775727
# Epoch 123/400, Validation Loss: 1.0276473968932347
# Epoch 124/400, Validation Loss: 1.0101198675753242
# Epoch 125/400, Validation Loss: 0.9927187740516095
# Epoch 126/400, Validation Loss: 0.9846879471375564
# Epoch 127/400, Validation Loss: 0.9689701118935753
# Epoch 128/400, Validation Loss: 0.9637671684179827
# Epoch 129/400, Validation Loss: 0.9495607836590944
# Epoch 130/400, Validation Loss: 0.9514872419723259
# Epoch 131/400, Validation Loss: 0.9440767809651659
# Epoch 132/400, Validation Loss: 0.9194163783417542
# Epoch 133/400, Validation Loss: 0.910052651533215
# Epoch 134/400, Validation Loss: 0.9004999886182479
# Epoch 135/400, Validation Loss: 0.893361923393844
# Epoch 136/400, Validation Loss: 0.8741394889028659
# Epoch 137/400, Validation Loss: 0.8696550485493549
# Epoch 138/400, Validation Loss: 0.8590635046545987
# Epoch 139/400, Validation Loss: 0.8585568931478319
# Epoch 140/400, Validation Loss: 0.8476294185877578
# Epoch 141/400, Validation Loss: 0.8358749708134342
# Epoch 142/400, Validation Loss: 0.8320974728029557
# Epoch 143/400, Validation Loss: 0.8211711904276184
# Epoch 144/400, Validation Loss: 0.8065106510832699
# Epoch 145/400, Validation Loss: 0.7972304941900761
# Epoch 146/400, Validation Loss: 0.7848857218847332
# Epoch 147/400, Validation Loss: 0.7809462436090049
# Epoch 148/400, Validation Loss: 0.7687476189696031
# Epoch 149/400, Validation Loss: 0.7696835009902742
# Epoch 150/400, Validation Loss: 0.7616757753288035
# Epoch 151/400, Validation Loss: 0.7567012424226285
# Epoch 152/400, Validation Loss: 0.742764068836565
# Epoch 153/400, Validation Loss: 0.7384048718153589
# Epoch 154/400, Validation Loss: 0.7289660270411402
# Epoch 155/400, Validation Loss: 0.7226931956010524
# Epoch 156/400, Validation Loss: 0.7157747429111979
# Epoch 157/400, Validation Loss: 0.7049107933424356
# Epoch 158/400, Validation Loss: 0.7077203836241478
# Epoch 159/400, Validation Loss: 0.704993015413737
# Epoch 160/400, Validation Loss: 0.691718693660816
# Epoch 161/400, Validation Loss: 0.6843226710578231
# Epoch 162/400, Validation Loss: 0.6783556133471889
# Epoch 163/400, Validation Loss: 0.6724348894082846
# Epoch 164/400, Validation Loss: 0.6746112025927087
# Epoch 165/400, Validation Loss: 0.661470011230705
# Epoch 166/400, Validation Loss: 0.65539619684181
# Epoch 167/400, Validation Loss: 0.6576006418740539
# Epoch 168/400, Validation Loss: 0.6479211786332606
# Epoch 169/400, Validation Loss: 0.6468346782517825
# Epoch 170/400, Validation Loss: 0.6360865813801618
# Epoch 171/400, Validation Loss: 0.6340267654791214
# Epoch 172/400, Validation Loss: 0.6374629066108762
# Epoch 173/400, Validation Loss: 0.628734039300631
# Epoch 174/400, Validation Loss: 0.6170932941300635
# Epoch 175/400, Validation Loss: 0.6175694923994943
# Epoch 176/400, Validation Loss: 0.605542202047159
# Epoch 177/400, Validation Loss: 0.6048725853981467
# Epoch 178/400, Validation Loss: 0.6060443271453512
# Epoch 179/400, Validation Loss: 0.597634279248924
# Epoch 180/400, Validation Loss: 0.5919950001906555
# Epoch 181/400, Validation Loss: 0.5969783394322534
# Epoch 182/400, Validation Loss: 0.5868634215821646
# Epoch 183/400, Validation Loss: 0.5802387327627094
# Epoch 184/400, Validation Loss: 0.5707717136750595
# Epoch 185/400, Validation Loss: 0.5648496311458994
# Epoch 186/400, Validation Loss: 0.5649034193371703
# Epoch 187/400, Validation Loss: 0.5584610495332974
# Epoch 188/400, Validation Loss: 0.5565155377942597
# Epoch 189/400, Validation Loss: 0.5504373335782002
# Epoch 190/400, Validation Loss: 0.5492573666874374
# Epoch 191/400, Validation Loss: 0.5461278572770385
# Epoch 192/400, Validation Loss: 0.5485419342168909
# Epoch 193/400, Validation Loss: 0.5439193161136382
# Epoch 194/400, Validation Loss: 0.5390530672088214
# Epoch 195/400, Validation Loss: 0.5330600260190346
# Epoch 196/400, Validation Loss: 0.5284223280701784
# Epoch 197/400, Validation Loss: 0.5336660828507933
# Epoch 198/400, Validation Loss: 0.5333635859663861
# Epoch 199/400, Validation Loss: 0.5363010115596735
# Epoch 200/400, Validation Loss: 0.518354838065906
# Epoch 201/400, Validation Loss: 0.5158450128125629
# Epoch 202/400, Validation Loss: 0.5111964628002357
# Epoch 203/400, Validation Loss: 0.5172223649229146
# Epoch 204/400, Validation Loss: 0.5045249307056936
# Epoch 205/400, Validation Loss: 0.505953389167771
# Epoch 206/400, Validation Loss: 0.5125199347843716
# Epoch 207/400, Validation Loss: 0.5134183916405783
# Epoch 208/400, Validation Loss: 0.5016733166803353
# Epoch 209/400, Validation Loss: 0.5010526042854748
# Epoch 210/400, Validation Loss: 0.49644602025658546
# Epoch 211/400, Validation Loss: 0.49772359230150426
# Epoch 212/400, Validation Loss: 0.4923453166888767
# Epoch 213/400, Validation Loss: 0.4893728708958928
# Epoch 214/400, Validation Loss: 0.4832576594378863
# Epoch 215/400, Validation Loss: 0.48383107767484723
# Epoch 216/400, Validation Loss: 0.47723523583671534
# Epoch 217/400, Validation Loss: 0.4744923328278309
# Epoch 218/400, Validation Loss: 0.4744352481817672
# Epoch 219/400, Validation Loss: 0.4777631049534167
# Epoch 220/400, Validation Loss: 0.4776445553281454
# Epoch 221/400, Validation Loss: 0.4761330610696417
# Epoch 222/400, Validation Loss: 0.47608192722161624
# Epoch 223/400, Validation Loss: 0.4686240825839868
# Epoch 224/400, Validation Loss: 0.47408962908797053
# Epoch 225/400, Validation Loss: 0.46892807956670346
# Epoch 226/400, Validation Loss: 0.4625717704382373
# Epoch 227/400, Validation Loss: 0.4655250594928594
# Epoch 228/400, Validation Loss: 0.46354341518395736
# Epoch 229/400, Validation Loss: 0.4647794052149388
# Epoch 230/400, Validation Loss: 0.45802801089870987
# Epoch 231/400, Validation Loss: 0.46875534102030825
# Epoch 232/400, Validation Loss: 0.45655700874596816
# Epoch 233/400, Validation Loss: 0.4525339235620991
# Epoch 234/400, Validation Loss: 0.44988176592743023
# Epoch 235/400, Validation Loss: 0.4545084351990246
# Epoch 236/400, Validation Loss: 0.4606518284061818
# Epoch 237/400, Validation Loss: 0.45063375826151775
# Epoch 238/400, Validation Loss: 0.4527543336255393
# Epoch 239/400, Validation Loss: 0.44804841344242546
# Epoch 240/400, Validation Loss: 0.4475079426590628
# Epoch 241/400, Validation Loss: 0.4470597067817058
# Epoch 242/400, Validation Loss: 0.4478321219593819
# Epoch 243/400, Validation Loss: 0.44549487323329606
# Epoch 244/400, Validation Loss: 0.43802332943862793
# Epoch 245/400, Validation Loss: 0.43842974488358655
# Epoch 246/400, Validation Loss: 0.43611492082807696
# Epoch 247/400, Validation Loss: 0.44025579534690296
# Epoch 248/400, Validation Loss: 0.43802323958066214
# Epoch 249/400, Validation Loss: 0.44596412638734273
# Epoch 250/400, Validation Loss: 0.43532999487688945
# Epoch 251/400, Validation Loss: 0.44237532821590914
# Epoch 252/400, Validation Loss: 0.44597746107516645
# Epoch 253/400, Validation Loss: 0.430959583762262
# Epoch 254/400, Validation Loss: 0.42849621796544957
# Epoch 255/400, Validation Loss: 0.4338490324922469
# Epoch 256/400, Validation Loss: 0.4264444630867331
# Epoch 257/400, Validation Loss: 0.4289816378703664
# Epoch 258/400, Validation Loss: 0.4252171969035811
# Epoch 259/400, Validation Loss: 0.4296946137498612
# Epoch 260/400, Validation Loss: 0.4301780339450526
# Epoch 261/400, Validation Loss: 0.42447525411833575
# Epoch 262/400, Validation Loss: 0.42445807828648074
# Epoch 263/400, Validation Loss: 0.42266763525886064
# Epoch 264/400, Validation Loss: 0.4251032994786422
# Epoch 265/400, Validation Loss: 0.43183784280161214
# Epoch 266/400, Validation Loss: 0.42604255083183934
# Epoch 267/400, Validation Loss: 0.42165471108858465
# Epoch 268/400, Validation Loss: 0.42503313440310037
# Epoch 269/400, Validation Loss: 0.42580437856177583
# Epoch 270/400, Validation Loss: 0.42187241683796817
# Epoch 271/400, Validation Loss: 0.42324124698655863
# Epoch 272/400, Validation Loss: 0.4212787316336044
# Epoch 273/400, Validation Loss: 0.4219339163407582
# Epoch 274/400, Validation Loss: 0.42043788348121247
# Epoch 275/400, Validation Loss: 0.41936453140880003
# Epoch 276/400, Validation Loss: 0.4178521191414369
# Epoch 277/400, Validation Loss: 0.4150153626307004
# Epoch 278/400, Validation Loss: 0.4177222731332205
# Epoch 279/400, Validation Loss: 0.4264307587881442
# Epoch 280/400, Validation Loss: 0.41911396774313825
# Epoch 281/400, Validation Loss: 0.4169917719104591
# Epoch 282/400, Validation Loss: 0.42161436479468756
# Epoch 283/400, Validation Loss: 0.41646713115442624
# Epoch 284/400, Validation Loss: 0.41765846075338553
# Epoch 285/400, Validation Loss: 0.4152519933543178
# Epoch 286/400, Validation Loss: 0.4176226656788183
# Epoch 287/400, Validation Loss: 0.42778763410802306
# Epoch 288/400, Validation Loss: 0.42521806293362713
# Epoch 289/400, Validation Loss: 0.42364384643430847
# Epoch 290/400, Validation Loss: 0.4186953732270647
# Epoch 291/400, Validation Loss: 0.42157238242095224
# Epoch 292/400, Validation Loss: 0.4112042331577455
# Epoch 293/400, Validation Loss: 0.4134462466081179
# Epoch 294/400, Validation Loss: 0.4133178326642016
# Epoch 295/400, Validation Loss: 0.41714869678146815
# Epoch 296/400, Validation Loss: 0.41393319831673736
# Epoch 297/400, Validation Loss: 0.41301345756462915
# Epoch 298/400, Validation Loss: 0.41951194617324594
# Epoch 299/400, Validation Loss: 0.4121394156137301
# Epoch 300/400, Validation Loss: 0.41652563520483643
# Epoch 301/400, Validation Loss: 0.4146846366996213
# Epoch 302/400, Validation Loss: 0.41376725241401
# Epoch 303/400, Validation Loss: 0.41219710911350116
# Epoch 304/400, Validation Loss: 0.4192663573402318
# Epoch 305/400, Validation Loss: 0.41911398128324884
# Epoch 306/400, Validation Loss: 0.4153364011474303
# Epoch 307/400, Validation Loss: 0.40883530176770916
# Epoch 308/400, Validation Loss: 0.41139845013348975
# Epoch 309/400, Validation Loss: 0.4180079451539731
# Epoch 310/400, Validation Loss: 0.42251551762931755
# Epoch 311/400, Validation Loss: 0.4165858302417421
# Epoch 312/400, Validation Loss: 0.4211592661083731
# Epoch 313/400, Validation Loss: 0.414455593139763
# Epoch 314/400, Validation Loss: 0.41662046203940656
# Epoch 315/400, Validation Loss: 0.41760533874095956
# Epoch 316/400, Validation Loss: 0.41351759193964305
# Epoch 317/400, Validation Loss: 0.410335292396591
# Epoch 318/400, Validation Loss: 0.41850334604828954
# Epoch 319/400, Validation Loss: 0.41368439653465544
# Epoch 320/400, Validation Loss: 0.41166720989930894
# Epoch 321/400, Validation Loss: 0.41635540243234753
# Epoch 322/400, Validation Loss: 0.4130572125101567
# Epoch 323/400, Validation Loss: 0.41172710554594777
# Epoch 324/400, Validation Loss: 0.40786878615839955
# Epoch 325/400, Validation Loss: 0.40920144059765545
# Epoch 326/400, Validation Loss: 0.410949348141587
# Epoch 327/400, Validation Loss: 0.41430220196830875
# Epoch 328/400, Validation Loss: 0.414084979306007
# Epoch 329/400, Validation Loss: 0.4128726303313888
# Epoch 330/400, Validation Loss: 0.41621116096403404
# Epoch 331/400, Validation Loss: 0.41131957797316926
# Epoch 332/400, Validation Loss: 0.41772833290024425
# Epoch 333/400, Validation Loss: 0.42066808901869573
# Epoch 334/400, Validation Loss: 0.4150162872729509
# Epoch 335/400, Validation Loss: 0.4209686261416369
# Epoch 336/400, Validation Loss: 0.42321822454162134
# Epoch 337/400, Validation Loss: 0.41544717131507297
# Epoch 338/400, Validation Loss: 0.41207232373299635
# Epoch 339/400, Validation Loss: 0.41651696243768493
# Epoch 340/400, Validation Loss: 0.414671880194789
# Epoch 341/400, Validation Loss: 0.40977195868791494
# Epoch 342/400, Validation Loss: 0.41010098732457845
# Epoch 343/400, Validation Loss: 0.41725469597525383
# Epoch 344/400, Validation Loss: 0.41495325464021127
# Epoch 345/400, Validation Loss: 0.41172127789839885
# Epoch 346/400, Validation Loss: 0.41610299707921505
# Epoch 347/400, Validation Loss: 0.4176957916954276
# Epoch 348/400, Validation Loss: 0.41783205352306496
# Epoch 349/400, Validation Loss: 0.4140172777899177
# Epoch 350/400, Validation Loss: 0.4120515938275922
# Epoch 351/400, Validation Loss: 0.4140784294251921
# Epoch 352/400, Validation Loss: 0.4157381425689207
# Epoch 353/400, Validation Loss: 0.41467485843347296
# Epoch 354/400, Validation Loss: 0.4133687136265979
# Epoch 355/400, Validation Loss: 0.41043648199539734
# Epoch 356/400, Validation Loss: 0.41363026528936875
# Epoch 357/400, Validation Loss: 0.41126478924338716
# Epoch 358/400, Validation Loss: 0.4126875832177509
# Epoch 359/400, Validation Loss: 0.4197609962599655
# Epoch 360/400, Validation Loss: 0.42151149226269136
# Epoch 361/400, Validation Loss: 0.41728860630600345
# Epoch 362/400, Validation Loss: 0.41511848567873655
# Epoch 363/400, Validation Loss: 0.41445676401203524
# Epoch 364/400, Validation Loss: 0.4168174436099469
# Epoch 365/400, Validation Loss: 0.4162768779831206
# Epoch 366/400, Validation Loss: 0.41474366268799523
# Epoch 367/400, Validation Loss: 0.41309898562117053
# Epoch 368/400, Validation Loss: 0.41157011397576493
# Epoch 369/400, Validation Loss: 0.41987686510890027
# Epoch 370/400, Validation Loss: 0.4254615343593103
# Epoch 371/400, Validation Loss: 0.41914234379861715
# Epoch 372/400, Validation Loss: 0.4138590451353453
# Epoch 373/400, Validation Loss: 0.4133193192485776
# Epoch 374/400, Validation Loss: 0.41570874250252077
# Epoch 375/400, Validation Loss: 0.42308721140123995
# Epoch 376/400, Validation Loss: 0.4230412967947149
# Epoch 377/400, Validation Loss: 0.4195305163031614
# Epoch 378/400, Validation Loss: 0.4237477415035119
# Epoch 379/400, Validation Loss: 0.4186327529215772
# Epoch 380/400, Validation Loss: 0.41771472410395083
# Epoch 381/400, Validation Loss: 0.41010861320779834
# Epoch 382/400, Validation Loss: 0.4145756028686064
# Epoch 383/400, Validation Loss: 0.4228776213807769
# Epoch 384/400, Validation Loss: 0.4201251161242556
# Epoch 385/400, Validation Loss: 0.41840864144088596
# Epoch 386/400, Validation Loss: 0.4196113877243066
# Epoch 387/400, Validation Loss: 0.42313947761630893
# Epoch 388/400, Validation Loss: 0.4140375316082294
# Epoch 389/400, Validation Loss: 0.4204793485101505
# Epoch 390/400, Validation Loss: 0.4127939133472281
# Epoch 391/400, Validation Loss: 0.415874904809197
# Epoch 392/400, Validation Loss: 0.4213733106436153
# Epoch 393/400, Validation Loss: 0.42336939012315933
# Epoch 394/400, Validation Loss: 0.4243534966857814
# Epoch 395/400, Validation Loss: 0.4175952315618943
# Epoch 396/400, Validation Loss: 0.4175185626391899
# Epoch 397/400, Validation Loss: 0.41670555471525306
# Epoch 398/400, Validation Loss: 0.42029306811005895
# Epoch 399/400, Validation Loss: 0.4238913606163105
# Epoch 400/400, Validation Loss: 0.42148627279850287

# %%
a_val, b_val = model.a.item(), model.b.item()

# Generate predictions for plotting
end_fit_x = [x_all[0], x_all[-1]]
end_fit_y = [a_val * x + b_val for x in end_fit_x] # Das ist das Trainierte Modell, das gemacht haben
true_fn_y = [a0 * x + b0 for x in end_fit_x]  # Assuming a0 and b0 are known true values - Notiz: Das ist quasi der 'wahre Wert' und wenn man über
#die variable a_val resp a0 drüber hovert, dann sieht man, dass die Werte nahe beieinander sind.

# Plotting
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plotting data points and model predictions
axs[0].plot(x_train, y_train, 'ro', x_val, y_val, 'b^', end_fit_x, end_fit_y, 'g')
axs[0].legend(('training points', 'test points', 'final fit'), loc='upper left')

# Assuming training and validation loss history are stored in lists: train_loss_history and val_loss_history
epochs = range(1, len(train_loss_history) + 1)

# Plotting loss history
axs[1].semilogy(epochs, train_loss_history, 'r')
axs[1].semilogy(epochs, val_loss_history, 'b')
axs[1].legend(('training loss', 'validation loss'), loc='upper right')

plt.show()

# %% [markdown]
# ## 3. Exercise 1
#
# Play with the true function parameters ```a0, b0, s0``` and the ``batch_size`` value, check how it affects the convergence.
#
# * Batch size: How long it takes to run. The longer it takes to run, then increase the batch size.
#
# 1. How change of `s0` affects convergance?
#
# * Wenn s0 grösser --> die Linie wird breiter
#
# 2. When one should stop training to prevent overfitting?
#
# * Wenn die Linien sich kreuzen? --> Ja
#
#
# ## 4. Training loop
#
# The training as we just saw is done iteratively, by adjusting the model parameters.
#
# We perform optimization several times for all traininng dataset. Going through all this dataset is refered to as 'epoch'.
#
# When we do training its usually done in two loops. In outer loop we iterate over all epochs. For each epoch we usually split the dataset into small chuncks, batches, and optimization it performed for all of those.
#
# It is important that data doesn't go to the training pipeline in same order. So the overall scheme looks like this (pseudocode):
#
#
# ```
# x,y = get_training_data()
# for epoch in range(number_epochs):
#    x_shfl,y_shfl = shuffle(x,y)
#
#    for mb_idx in range(number_minibatches_in_batch):
#        x_mb,y_mb = get_minibatch(x_shfl,y_shfl, mb_idx)
#
#        optimize_on(data=x_mb, labels=y_mb)
# ```
#
# ## 5. Bulding blocks of a neural network
#
# Neural network consists of layers of neurons. Each neuron perfroms 2 operations.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/Perceptron.png" alt="drawing" width="30%"/>
#
# Each neuron performs 2 operations.
#
# 1. Calculate the linear transformation of the input vector $\mathbf{x}_i$:
# $$z_i = \mathbf{w} \cdot \mathbf{x}_i + b = \sum_j {w_j x_{ij}} + b$$ where $\mathbf{w}$ is a weight vector and $b$ - a bias, and $j$ traverses each dimension of the input vector
# 2. Perform the nonlinear transformation of the result using the activation function $f$ $$y_i = f(z_i)$$
#
# In a fully connected neural network, each layer is a set of N neurons, performing different transformations of the input $\mathbf{x}_i$ of the same layer, now producing an output **vector** $ \mathbf{y} _i = f(\mathbf{z}_i) = f(W\mathbf{x}_i + \mathbf{b})$ now with a bias vector $\mathbf{b}$ and a * *matrix** of weights $W$.
#
# Since the output of each layer constitutes the input to the next layer, we can write for layer $l$: $$\mathbf{x}^l_i = f^{l-1}(\mathbf{W}^{ l-1} \mathbf{x}^{ l-1}_i + \mathbf{b}^{l-1})$$ where $\mathbf{x}_i^{l=0}$ is the vector d 'network input for data point $i$.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/MLP.png" alt="drawing" width="50%"/>
#
# To simplify building the network, we'll define a helper function, creating neuron layer with given number of outputs:

# %%
class Dense(nn.Module):
    def __init__(self, input_units, output_units, activation=None):
        """
        Fully connected layer implemented with explicit matrix multiplication.

        Parameters
        ----------
        input_units : int
            Number of input neurons
        output_units : int
            Number of output neurons
        activation : callable or None, optional
            Non-linear activation function (e.g., F.relu)
        """
        super(Dense, self).__init__()
        self.input_units = int(input_units)
        self.output_units = int(output_units)
        self.activation = activation

        # Initialize weights and biases
        self.weights = nn.Parameter(torch.randn(input_units, output_units))
        self.bias = nn.Parameter(torch.randn(output_units))

    def forward(self, x):
        """
        Forward pass through the layer.

        Parameters
        ----------
        x : torch.Tensor
            Input tensor

        Returns
        -------
        torch.Tensor
            Output of the layer
        """

        outputs = torch.matmul(x, self.weights) + self.bias

        # Apply activation function if provided
        if self.activation is not None:
            # Check if the activation function is softmax
            if self.activation == F.softmax:
                # Apply softmax with specified dimension
                outputs = self.activation(outputs, dim=1)
            else:
                # apply other activation functions normally
                outputs = self.activation(outputs)

        return outputs

# %% [markdown]
# In the case of multi-class classification, in the last layer, we can use the *softmax* transformation as a non-linear transformation. The softmax for the $j$th element of $\mathbf{z}_i$ is $$y_{ij} = \frac{e^{z_{ij}}}{\sum_{k=1}^{K} e^{z_{ik}}}$$ where $K$ is the total number of classes.
#
#
# For example. before softmax $$[1.0, 2.0, 3.0, \mathbf{4.0} ]$$ and after: $$[0.0321, 0.0871, 0.2369, \mathbf{0.6439}]$$ (now the sum is equal to one)
#
# We can also now compare the fundamental truth which could be $$[0,0,0,\mathbf{1}]$$ That is to say that class 4 is the good class and that the network predicted correctly.
# ## 6. Bulding a neural network
#
# https://medium.com/geekculture/how-visualizations-help-make-sense-of-deep-learning-a408ab00688f

# %%
n_input = 10
n_output = 2
num_datapoints = 1
input_tensor = torch.randn(num_datapoints, n_input)
dense = Dense(input_units=n_input , output_units=n_output, activation=torch.sigmoid)


# remember to matrix multiply A and B we need the shapes (a1 x a2) (b1 x b2) to be such that a2=b1
# the result will be (a1 x b2)

print(dense.weights.shape)
print(input_tensor.shape)
print(torch.matmul(input_tensor, dense.weights).shape) # this is XW  e.g. (1, 10)x(10, 2) = (1 x 2)

# notice that increasing the number of data points does not change the shape of W!
# This is important - the parameter shape should not change according to the number of datapoints, only their dimensionality

# Notiz: This was one example with one layer
# Out:
# torch.Size([10, 2])
# torch.Size([1, 10])
# torch.Size([1, 2])

# %%
# if we want to stack multiple dense operations together
hidden_dim = 10 # Notiz: = 10 Neurons in the hidden layer
dense1 =  Dense(input_units=n_input , output_units=hidden_dim, activation=torch.sigmoid)
dense2 =  Dense(input_units=hidden_dim , output_units=n_output, activation=F.softmax)
output = dense2(dense1(input_tensor))

#Notiz: Here we have 2 Layers, deshalb 2 outputs/Zeilen Code. Wenn wir dense3 hätten, also 3 Layer, dann würde man hidden_dim2 haben dort wo jetzt n_output steht.
# Und activation wäre sigmoid und man hätte dann eine weitere layer:
#dense3 = Dense(input_units = hidden_dim2, output_units=n_output, activation=F.softmax)
# Und die output line wäre dann:
# output = dense3(dense2(dense1(input_tensor)))

#the activation that we have to use for the last layer is defined by the task we do --> wir brauchen hier softmax, weil wir eine classification machen (glaube ich)
#in diesem beispiel wird sigmoid benutzt als beispiel, aber sie empfiehlt torch.relu zu verwenden, das ist besser

# %%
# integrate everything into an overall model

class MyModel(nn.Module):
    def __init__(self, input_units, hidden_units, output_units):
        super(MyModel, self).__init__()
        # Define a Dense layer
        self.dense1 = Dense(input_units, hidden_units, activation=F.relu)
            #Notiz: Dense = Fully connected layer
        # Define another Dense layer
        self.dense2 = Dense(hidden_units, output_units, activation=F.softmax)

    def forward(self, x):
        x = self.dense1(x)
        x = self.dense2(x)
        return x

    def predict(self, x):
        # Forward pass and get predictions
        preds = self.dense2(self.dense1(x))
        print(preds)  # to check values before argmax
        return torch.argmax(preds, dim=1)

# Example usage
input_units = 10
hidden_units = 5
output_units = 2
model = MyModel(input_units, hidden_units, output_units)

# Create a sample input tensor
input_tensor = torch.randn(5, input_units)

# Get predictions
predictions = model.predict(input_tensor)
print(predictions)
# Out:
# tensor([[9.9717e-01, 2.8296e-03],
#         [7.6092e-01, 2.3908e-01],
#         [1.0570e-04, 9.9989e-01],
#         [8.4924e-03, 9.9151e-01],
#         [9.9999e-01, 5.0601e-06]], grad_fn=<SoftmaxBackward0>)
# tensor([0, 0, 1, 1, 0])
